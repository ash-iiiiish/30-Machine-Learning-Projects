# %% [markdown]
# # Diabetes Prediction

# %% [markdown]
# ## Importing Libraries

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ## Training Model

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Thanks!
